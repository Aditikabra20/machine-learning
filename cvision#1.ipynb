# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditikabra20/machine-learning/blob/ml/cvision%231.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
#read one image
img1=cv2.imread('download1.jpg')

# %%
# read another image
img2=cv2.imread('download2.jpg')

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=238x212 at 0x7F58A1903E10>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=238x212 at 0x7F58A181E3C8>

# %%
#replace part
img1[100:200,100:200]=img2[100:200,100:200]

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=238x212 at 0x7F58A181E780>

# %%
img3=cv2.imread('download1.jpg')

# %%
img4=cv2.imread('download2.jpg')

# %%
img4[100:200,100:200]=img3[100:200,100:200]

# %%
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=238x212 at 0x7F58A181E898>

# %%
img5=cv2.imread('download.jpg')

# %%
cv2_imshow(img5)
# Out:
# <PIL.Image.Image image mode=RGB size=244x207 at 0x7F58A181E470>

# %%
#replace 10 row an 20 colums
img4[50:60,50:70]=img5[100:110,100:120]

# %%
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=238x212 at 0x7F58A181EA90>
