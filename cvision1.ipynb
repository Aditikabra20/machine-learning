# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditikabra20/machine-learning/blob/ml/cvision1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
#read one image
img1=cv2.imread('download1.jpg')

# %%
# read another image
img2=cv2.imread('download2.jpg')

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=238x212 at 0x7F60AB6BBF98>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=238x212 at 0x7F60AB5DE710>

# %%
crop1=img1[100:200,100:200]

# %%
cv2_imshow(crop1)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F60B3DF6E10>

# %%
crop2=img2[100:200,100:200]

# %%
cv2_imshow(crop2)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F60AB5DE6A0>

# %%
img1[0:100,0:100]=crop2

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=238x212 at 0x7F60AB5DE978>

# %%
img2[0:100,0:100]=crop1

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=238x212 at 0x7F60AB5DEB38>

# %%
img2.shape
# Out:
# (212, 238, 3)

# %%
from google.colab.patches import cv2_imshow

# %%
img3=cv2.imread('download.jpg')

# %%
img2[150:160,150:170]=img3[100:110,100:120]

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=238x212 at 0x7F60A9D7F198>
